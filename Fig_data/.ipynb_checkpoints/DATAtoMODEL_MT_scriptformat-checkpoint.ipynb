# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy.stats as stats
import pandas as pd

plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
sb.set_context("paper", rc={"font.size":16,"axes.titlesize":18,"axes.labelsize":16})

# %% [markdown]
# # fit quality <a name="pseudoR"></a>
# [content](#content)
#
# below is the pseudo-R measure of the stimulus response model in comparison to a mean-rate model and of the SR model + V1-modulator compared to just the SR model

# %%
#dfnew = df.loc[:,'modulated SR']
#dfnew.to_excel('Fig_6C.xlsx', engine='openpyxl', index=False)

# %% [markdown]
# ### compare to V1 statistics

# %%
# dfnew = df.loc[:,('MT_inf_more', 'MT_fit')]
# dfnew.to_excel('Fig_6D.xlsx', engine='openpyxl', index=False)
